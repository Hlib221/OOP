# %% [markdown]
# моя перша програма

# %%
from datetime import datetime
name = "Gleb"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Gleb start programming at 2025-09-18 18:37:02.528514. Lviv is the best city!
